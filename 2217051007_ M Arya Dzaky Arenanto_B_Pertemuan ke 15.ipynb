# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rahmantaufik27/dataset/main/study/churn_bank_customer.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe().transpose()
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# CustomerId       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# CreditScore           584.00  6.520000e+02  7.180000e+02       850.00
# Age                    32.00  3.700000e+01  4.400000e+01        92.00
# Tenure                  3.00  5.000000e+00  7.000000e+00        10.00
# Balance                 0.00  9.719854e+04  1.276442e+05    250898.09
# NumOfProducts           1.00  1.000000e+00  2.000000e+00         4.00
# HasCrCard               0.00  1.000000e+00  1.000000e+00         1.00
# IsActiveMember          0.00  1.000000e+00  1.000000e+00         1.00
# EstimatedSalary     51002.11  1.001939e+05  1.493882e+05    199992.48
# Exited                  0.00  0.000000e+00  0.000000e+00         1.00

# %% [markdown]
# # Preprocessing

# %%
Y = df.iloc[:, -1].values
X = df.iloc[:, 3:-1].values
print(X)
print(Y)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]
# [1 0 1 ... 1 1 0]

# %%
lc = LabelEncoder()
X[:, 2] = np.array(lc.fit_transform(X[:, 2]))
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
print(X)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model_ann = tf.keras.Sequential([
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid'),
])

model_ann.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])

model_ann.fit(X_train, Y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 4s 3ms/step - loss: 0.5276 - accuracy: 0.7916
# Epoch 2/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4581 - accuracy: 0.8043
# Epoch 3/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4402 - accuracy: 0.8124
# Epoch 4/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4331 - accuracy: 0.8110
# Epoch 5/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4295 - accuracy: 0.8119
# Epoch 6/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.8136
# Epoch 7/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4248 - accuracy: 0.8142
# Epoch 8/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8155
# Epoch 9/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4213 - accuracy: 0.8184
# Epoch 10/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4193 - accuracy: 0.8213
# Epoch 11/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4174 - accuracy: 0.8207
# Epoch 12/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4159 - accuracy: 0.8246
# Epoch 13/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4149 - accuracy: 0.8246
# Epoch 14/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4135 - accuracy: 0.8269
# Epoch 15/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4125 - accuracy: 0.8295
# Epoch 16/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4117 - accuracy: 0.8281
# Epoch 17/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4107 - accuracy: 0.8300
# Epoch 18/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4102 - accuracy: 0.8320
# Epoch 19/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4093 - accuracy: 0.8320
# Epoch 20/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4089 - accuracy: 0.8322
# Epoch 21/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4085 - accuracy: 0.8329
# Epoch 22/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4076 - accuracy: 0.8329
# Epoch 23/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.8326
# Epoch 24/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4068 - accuracy: 0.8331
# Epoch 25/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8334
# Epoch 26/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8321
# Epoch 27/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8355
# Epoch 28/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8345
# Epoch 29/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8341
# Epoch 30/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8332
# Epoch 31/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8345
# Epoch 32/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.8329
# Epoch 33/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8351
# Epoch 34/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8350
# Epoch 35/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8355
# Epoch 36/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3978 - accuracy: 0.8359
# Epoch 37/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8356
# Epoch 38/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8365
# Epoch 39/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8367
# Epoch 40/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3916 - accuracy: 0.8385
# Epoch 41/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3895 - accuracy: 0.8407
# Epoch 42/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3871 - accuracy: 0.8409
# Epoch 43/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3858 - accuracy: 0.8415
# Epoch 44/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3841 - accuracy: 0.8405
# Epoch 45/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3818 - accuracy: 0.8449
# Epoch 46/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3803 - accuracy: 0.8426
# Epoch 47/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3790 - accuracy: 0.8443
# Epoch 48/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3774 - accuracy: 0.8468
# Epoch 49/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8460
# Epoch 50/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.8456
# Epoch 51/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3730 - accuracy: 0.8478
# Epoch 52/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8499
# Epoch 53/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.8497
# Epoch 54/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3691 - accuracy: 0.8499
# Epoch 55/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3685 - accuracy: 0.8500
# Epoch 56/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3668 - accuracy: 0.8512
# Epoch 57/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3663 - accuracy: 0.8521
# Epoch 58/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3653 - accuracy: 0.8506
# Epoch 59/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3645 - accuracy: 0.8510
# Epoch 60/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3634 - accuracy: 0.8521
# Epoch 61/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8531
# Epoch 62/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8540
# Epoch 63/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8546
# Epoch 64/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3606 - accuracy: 0.8533
# Epoch 65/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3598 - accuracy: 0.8537
# Epoch 66/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3600 - accuracy: 0.8537
# Epoch 67/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3592 - accuracy: 0.8537
# Epoch 68/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3582 - accuracy: 0.8537
# Epoch 69/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3580 - accuracy: 0.8546
# Epoch 70/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3572 - accuracy: 0.8533
# Epoch 71/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3569 - accuracy: 0.8568
# Epoch 72/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3563 - accuracy: 0.8550
# Epoch 73/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3554 - accuracy: 0.8570
# Epoch 74/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3554 - accuracy: 0.8566
# Epoch 75/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3546 - accuracy: 0.8547
# Epoch 76/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.8576
# Epoch 77/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3535 - accuracy: 0.8571
# Epoch 78/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3530 - accuracy: 0.8579
# Epoch 79/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.8576
# Epoch 80/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.8589
# Epoch 81/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3507 - accuracy: 0.8591
# Epoch 82/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3498 - accuracy: 0.8576
# Epoch 83/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8579
# Epoch 84/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3482 - accuracy: 0.8594
# Epoch 85/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3478 - accuracy: 0.8584
# Epoch 86/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3472 - accuracy: 0.8595
# Epoch 87/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8606
# Epoch 88/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3457 - accuracy: 0.8595
# Epoch 89/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.8585
# Epoch 90/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3451 - accuracy: 0.8612
# Epoch 91/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3446 - accuracy: 0.8595
# Epoch 92/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3436 - accuracy: 0.8616
# Epoch 93/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3430 - accuracy: 0.8610
# Epoch 94/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3427 - accuracy: 0.8621
# Epoch 95/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3420 - accuracy: 0.8625
# Epoch 96/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3415 - accuracy: 0.8610
# Epoch 97/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3408 - accuracy: 0.8621
# Epoch 98/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3406 - accuracy: 0.8616
# Epoch 99/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3406 - accuracy: 0.8604
# Epoch 100/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3401 - accuracy: 0.8604

# %%
model_ann.evaluate(X_test, Y_test, batch_size=8)
# Out:
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3399 - accuracy: 0.8610
# [0.33992907404899597, 0.8610000014305115]

# %%
print(model_ann.predict(sc.transform([[1,0,0,600,1,40,3,60000,2,1,1,50000]])) > 0.5)
# Out:
# 1/1 [==============================] - 0s 155ms/step
# [[False]]
